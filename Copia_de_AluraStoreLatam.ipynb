# %% [markdown]
# ## Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# 1  Tarjeta de crédito                   4  6.25184 -75.56359
# 2  Tarjeta de crédito                  10  4.81333 -75.69611
# 3  Tarjeta de crédito                  10  3.43722 -76.52250
# 4  Tarjeta de crédito                   3  4.60971 -74.08175

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# 1  Tarjeta de crédito                   1   3.43722 -76.52250
# 2  Tarjeta de crédito                   3   4.60971 -74.08175
# 3  Tarjeta de crédito                   6  10.96854 -74.78132
# 4  Tarjeta de crédito                   1   4.60971 -74.08175

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# 1  Tarjeta de crédito                   2  7.89391 -72.50782
# 2               Nequi                   1  6.25184 -75.56359
# 3               Nequi                   1  6.25184 -75.56359
# 4  Tarjeta de crédito                   7  4.60971 -74.08175

# %%
type(tienda)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tienda2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tienda3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tienda4)
# Out:
# pandas.core.frame.DataFrame

# %%
tienda.sample(10)
# Out:
#                        Producto  Categoría del Producto     Precio  \
# 856                      Sillón                 Muebles   235300.0
# 1576          Asistente virtual            Electrónicos   121700.0
# 268                      Sillón                 Muebles   227000.0
# 1758         Guitarra eléctrica  Instrumentos musicales   793900.0
# 1773                 Smartwatch            Electrónicos   166200.0
# 1330              TV LED UHD 4K            Electrónicos  1678500.0
# 2184             Dinosaurio Rex                Juguetes    16100.0
# 1327  Auriculares con micrófono            Electrónicos    57200.0
# 1012                    Mochila    Deportes y diversión   104300.0
# 656                   Bicicleta    Deportes y diversión   627500.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 856          10700.0      15/05/2022    Juliana Costa            Cali
# 1576          4700.0      23/07/2021   Blanca Ramirez          Bogotá
# 268          10300.0      25/11/2021    Juliana Costa       Cartagena
# 1758         40500.0      11/01/2020   Juan Fernandez        Medellín
# 1773          9100.0      09/03/2022    Maria Alfonso          Bogotá
# 1330         87600.0      03/10/2020   Blanca Ramirez          Bogotá
# 2184             0.0      07/02/2022  Ángel Rodriguez          Bogotá
# 1327          3300.0      23/10/2021    Maria Alfonso        Medellín
# 1012          6100.0      06/03/2023    Lucas Olivera        Medellín
# 656          34100.0      01/01/2023    Maria Alfonso          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 856              4  Tarjeta de crédito                   1   3.43722 -76.52250
# 1576             5               Cupón                   1   4.60971 -74.08175
# 268              5  Tarjeta de crédito                   1  10.39972 -75.51444
# 1758             5  Tarjeta de crédito                   5   6.25184 -75.56359
# 1773             5  Tarjeta de crédito                   6   4.60971 -74.08175
# 1330             5  Tarjeta de crédito                   1   4.60971 -74.08175
# 2184             4  Tarjeta de crédito                   1   4.60971 -74.08175
# 1327             4               Nequi                   1   6.25184 -75.56359
# 1012             1  Tarjeta de crédito                   3   6.25184 -75.56359
# 656              5  Tarjeta de crédito                   1   4.60971 -74.08175

# %%
tienda2.sample(10)
# Out:
#                        Producto   Categoría del Producto     Precio  \
# 305               Kit de bancas                  Muebles   275400.0
# 456                   Cama king                  Muebles   443300.0
# 1382            Sofá reclinable                  Muebles   645000.0
# 2252                  Pandereta   Instrumentos musicales    73800.0
# 1765               Set de ollas  Artículos para el hogar   159300.0
# 1137           Secadora de ropa        Electrodomésticos  1036600.0
# 2224  Iniciando en programación                   Libros    42400.0
# 1171  Carrito de control remoto                 Juguetes    77200.0
# 258               TV LED UHD 4K             Electrónicos  2726800.0
# 1606              Kit de bancas                  Muebles   324800.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 305          12900.0      04/09/2022    Juliana Costa          Bogotá
# 456          26000.0      28/09/2020    Camila Rivera        Medellín
# 1382         34900.0      15/11/2020  Ángel Rodriguez     Santa Marta
# 2252          4600.0      13/11/2020  Beatriz Morales          Bogotá
# 1765          8900.0      15/01/2022  Mariana Herrera       Cartagena
# 1137         55700.0      17/09/2020    Rafael Acosta          Bogotá
# 2224          2800.0      16/06/2020  Beatriz Morales          Bogotá
# 1171          4300.0      30/06/2020  Ángel Rodriguez          Cúcuta
# 258         143400.0      30/01/2022    Camila Rivera          Bogotá
# 1606         17700.0      07/03/2020   Santiago Silva         Leticia
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 305              5               Nequi                   1   4.60971 -74.08175
# 456              4  Tarjeta de crédito                   7   6.25184 -75.56359
# 1382             5               Nequi                   1  11.24079 -74.19904
# 2252             4  Tarjeta de crédito                   3   4.60971 -74.08175
# 1765             5  Tarjeta de crédito                  10  10.39972 -75.51444
# 1137             5               Cupón                   1   4.60971 -74.08175
# 2224             5  Tarjeta de crédito                   9   4.60971 -74.08175
# 1171             1  Tarjeta de crédito                   1   7.89391 -72.50782
# 258              5  Tarjeta de crédito                   1   4.60971 -74.08175
# 1606             1  Tarjeta de crédito                   3  -4.21528 -69.94056

# %%
tienda3.sample(10)
# Out:
#               Producto   Categoría del Producto     Precio  Costo de envío  \
# 2107     Kit de bancas                  Muebles   296100.0         21600.0
# 2089            Sillón                  Muebles   236400.0         13000.0
# 419           Smart TV             Electrónicos  1763200.0         94100.0
# 1804        Microondas        Electrodomésticos   543700.0         29300.0
# 1416      Refrigerador        Electrodomésticos  1826700.0         95500.0
# 1993          Cama box                  Muebles   525000.0         26100.0
# 139    Sofá reclinable                  Muebles   621800.0         31300.0
# 1963   Olla de presión  Artículos para el hogar    74900.0          5000.0
# 141   Secadora de ropa        Electrodomésticos   886700.0         52000.0
# 1887    Dinosaurio Rex                 Juguetes    16200.0          5500.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 2107      24/03/2023    Rafael Acosta          Bogotá             5
# 2089      29/09/2021    Lucas Olivera           Pasto             5
# 419       28/07/2020  Ángel Rodriguez            Cali             2
# 1804      08/01/2020    Juliana Costa          Bogotá             1
# 1416      08/04/2021  Izabela de León          Bogotá             2
# 1993      14/09/2020    Maria Alfonso          Bogotá             5
# 139       21/01/2022    Juliana Costa        Medellín             5
# 1963      14/03/2020    Lucas Olivera          Bogotá             5
# 141       10/04/2020      Pedro Gomez          Bogotá             5
# 1887      13/09/2022  Izabela de León        Medellín             1
#
#           Método de pago  Cantidad de cuotas      lat       lon
# 2107  Tarjeta de crédito                   1  4.60971 -74.08175
# 2089  Tarjeta de crédito                   3  1.21361 -77.28111
# 419                Nequi                   1  3.43722 -76.52250
# 1804  Tarjeta de crédito                   1  4.60971 -74.08175
# 1416  Tarjeta de crédito                   3  4.60971 -74.08175
# 1993  Tarjeta de crédito                   2  4.60971 -74.08175
# 139                Cupón                   1  6.25184 -75.56359
# 1963               Nequi                   1  4.60971 -74.08175
# 141   Tarjeta de crédito                   1  4.60971 -74.08175
# 1887  Tarjeta de crédito                   6  6.25184 -75.56359

# %%
tienda4.sample(10)
# Out:
#                      Producto   Categoría del Producto     Precio  \
# 1462        Guitarra acústica   Instrumentos musicales   283000.0
# 738                   Mochila     Deportes y diversión   107900.0
# 1014            Juego de mesa                 Juguetes   117600.0
# 2212                Pandereta   Instrumentos musicales    72100.0
# 360   Dashboards con Power BI                   Libros    38800.0
# 627           Sofá reclinable                  Muebles   643700.0
# 1268      Modelado predictivo                   Libros    56800.0
# 1267                 Cama box                  Muebles   722700.0
# 1260             Set de vasos  Artículos para el hogar    26800.0
# 922                  Smart TV             Electrónicos  1675800.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 1462         13300.0      08/03/2022    Lucas Olivera            Cali
# 738           3900.0      10/07/2022    Rafael Acosta        Medellín
# 1014         13100.0      16/06/2021   Santiago Silva            Cali
# 2212          4200.0      16/09/2020   Santiago Silva        Medellín
# 360           2300.0      01/11/2022    Maria Alfonso          Bogotá
# 627          32500.0      13/09/2022    Maria Alfonso        Medellín
# 1268          8900.0      09/08/2021  Ángel Rodriguez        Medellín
# 1267         36700.0      16/03/2023    Felipe Santos          Bogotá
# 1260          1800.0      14/06/2021    Lucas Olivera         Pereira
# 922          89400.0      19/11/2020    Lucas Olivera          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas      lat       lon
# 1462             5  Tarjeta de crédito                   1  3.43722 -76.52250
# 738              5  Tarjeta de crédito                   4  6.25184 -75.56359
# 1014             5  Tarjeta de crédito                   1  3.43722 -76.52250
# 2212             1  Tarjeta de crédito                   6  6.25184 -75.56359
# 360              5  Tarjeta de crédito                   1  4.60971 -74.08175
# 627              3  Tarjeta de crédito                   3  6.25184 -75.56359
# 1268             3  Tarjeta de crédito                   1  6.25184 -75.56359
# 1267             5               Cupón                   1  4.60971 -74.08175
# 1260             1  Tarjeta de crédito                   8  4.81333 -75.69611
# 922              5  Tarjeta de crédito                   3  4.60971 -74.08175

# %%
tienda.shape
# Out:
# (2359, 12)

# %%
tienda2.shape
# Out:
# (2359, 12)

# %%
tienda3.shape
# Out:
# (2359, 12)

# %%
tienda4.shape
# Out:
# (2358, 12)

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda2.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda3.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda4.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# #1. Análisis de facturación
#
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
tienda.Precio.sum()
print(f'Ingreso_tienda:  ${tienda.Precio.sum():,.2f}')
tienda2.Precio.sum()
print(f'Ingreso_tienda 2:${tienda2.Precio.sum():,.2f}')
tienda3.Precio.sum()
print(f'Ingreso_tienda 3:${tienda3.Precio.sum():,.2f}')
tienda4.Precio.sum()
print(f'Ingreso_tienda 4:${tienda4.Precio.sum():,.2f}')
# Out:
# Ingreso_tienda:  $1,150,880,400.00
# Ingreso_tienda 2:$1,116,343,500.00
# Ingreso_tienda 3:$1,098,019,600.00
# Ingreso_tienda 4:$1,038,375,700.00

# %%
ingreso_total = (tienda.Precio.sum() + tienda2.Precio.sum() + tienda3.Precio.sum() + tienda4.Precio.sum())
print(f'ingreso_total:${ingreso_total:,.2f}')
# Out:
# ingreso_total:$4,403,619,200.00

# %%
dif_ing=(tienda.Precio.sum() - tienda4.Precio.sum())
print(f'Diferencia de ingresos de tienda1 y tienda4: ${dif_ing:,.2f}')
#dif_ing2=(tienda3.Precio.sum() - tienda4.Precio.sum())
#dif_ing_total=(dif_ing + dif_ing2)
#print(f'Diferencia_ingresos:${dif_ing_total:,.2f}')
# Out:
# Diferencia de ingresos de tienda1 y tienda4: $112,504,700.00

# %% [markdown]
# ###### Con nuestro primer análisis, vemos que la tienda 4 es la que tiene menos ingresos, lo que la convierte en foco para observar si es la que debe cerrar.
#
# También vemos en otro análisis, que la diferencia de ingresos vs la tienda 1 "que es la que más ventas reporta" es considerable, por lo que es otro punto a observar para determinar el cierre o no de la tienda.

# %% [markdown]
# # 2. Ventas por categoría
#
# En este debes calcular:
#
#  * la cantidad de productos vendidos por categoría en cada tienda.
#  * La idea es agrupar los datos por categoría y
#  * contar el número de ventas de cada tipo,
#  * mostrando las categorías más populares de cada tienda.

# %%
print(f'Categorías más populares en Tienda 1:')
tienda['Categoría del Producto'].value_counts()
# Out:
# Categorías más populares en Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
print('Total de artículos vendidos en Tienda 1: ', cat_tienda1.sum())
# Out:
# Total de artículos vendidos en Tienda 1:  2359

# %%
print(f'Categorías más populares en Tienda 2:')
tienda2['Categoría del Producto'].value_counts()
# Out:
# Categorías más populares en Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
print('Total de artículos vendidos en Tienda 2: ', cat_tienda2.sum())
# Out:
# Total de artículos vendidos en Tienda 2:  2359

# %%
print(f'Categorías más populares en Tienda 3:')
tienda3['Categoría del Producto'].value_counts()
# Out:
# Categorías más populares en Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
print('Total de artículos vendidos en Tienda 3: ', cat_tienda3.sum())
# Out:
# Total de artículos vendidos en Tienda 3:  2359

# %%
print(f'Categorías más populares en Tienda 4:')
tienda4['Categoría del Producto'].value_counts()
# Out:
# Categorías más populares en Tienda 4:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
print('Total de artículos vendidos en Tienda 4: ', cat_tienda4.sum())
# Out:
# Total de artículos vendidos en Tienda 4:  2358

# %%
# This cell previously caused `tienda` to be reassigned to an int.
# The sum of category counts can be calculated without overwriting the DataFrame.
# The individual category counts are already stored in cat_tienda1.
# We can print the sum of cat_tienda1 if needed.
print(cat_tienda1.sum())
# Out:
# 2359

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ventas por categoría para Tienda 1
plt.figure(figsize=(12, 6))
cat_tienda1.plot(kind='bar', color='purple')
plt.title('Ventas por Categoría en Tienda 1')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de Ventas')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Ventas por categoría para Tienda 2
plt.figure(figsize=(12, 6))
cat_tienda2.plot(kind='bar', color='pink')
plt.title('Ventas por Categoría en Tienda 2')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de Ventas')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Ventas por categoría para Tienda 3
plt.figure(figsize=(12, 6))
cat_tienda3.plot(kind='bar', color='green')
plt.title('Ventas por Categoría en Tienda 3')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de Ventas')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Ventas por categoría para Tienda 4
plt.figure(figsize=(12, 6))
cat_tienda4.plot(kind='bar', color='grey')
plt.title('Ventas por Categoría en Tienda 4')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de Ventas')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
print(f'Calificación promedio de Tienda 1: {tienda.Calificación.mean():.2f}')
print(f'Calificación promedio de Tienda 2: {tienda2.Calificación.mean():.2f}')
print(f'Calificación promedio de Tienda 3: {tienda3.Calificación.mean():.2f}')
print(f'Calificación promedio de Tienda 4: {tienda4.Calificación.mean():.2f}')
# Out:
# Calificación promedio de Tienda 1: 3.98
# Calificación promedio de Tienda 2: 4.04
# Calificación promedio de Tienda 3: 4.05
# Calificación promedio de Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
print(' +++  Productos más y menos vendidos en Tienda 1 +++ ')
print(f' *** Lista de 5 productos más vendidos: ***')
print(tienda['Producto'].value_counts().head(5))
print(f'*** Lista de 5 productos menos vendidos: ***')
print(tienda['Producto'].value_counts().tail(5))
# Out:
#  +++  Productos más y menos vendidos en Tienda 1 +++
#  *** Lista de 5 productos más vendidos: ***
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# *** Lista de 5 productos menos vendidos: ***
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %%
print('+++  Productos más y menos vendidos en Tienda 2 +++ ')
print(f' *** Lista de 5 productos más vendidos: ***')
print(tienda2['Producto'].value_counts().head(5))
print(f'*** Lista de 5 productos menos vendidos: ***')
print(tienda2['Producto'].value_counts().tail(5))
# Out:
# +++  Productos más y menos vendidos en Tienda 2 +++
#  *** Lista de 5 productos más vendidos: ***
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# *** Lista de 5 productos menos vendidos: ***
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64

# %%
print(f'+++ Productos más y menos vendidos en Tienda 3 +++ ')
print(f'*** Lista de 5 productos más vendidos:***')
print(tienda3['Producto'].value_counts().head(5))
print(f'*** Lista de 5 productos menos vendidos: ***')
print(tienda3['Producto'].value_counts().tail(5))
# Out:
# +++ Productos más y menos vendidos en Tienda 3 +++
# *** Lista de 5 productos más vendidos:***
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64
# *** Lista de 5 productos menos vendidos: ***
# Producto
# Guitarra eléctrica         38
# Set de vasos               36
# Mochila                    36
# Microondas                 36
# Bloques de construcción    35
# Name: count, dtype: int64

# %%
print(f'+++ Productos más y menos vendidos en Tienda 4 +++')
print(f'*** Lista de 5 productos más vendidos:***')
print(tienda4['Producto'].value_counts().head(5))
print(f'*** Lista de 5 productos menos vendidos: ***')
print(tienda4['Producto'].value_counts().tail(5))
# Out:
# +++ Productos más y menos vendidos en Tienda 4 +++
# *** Lista de 5 productos más vendidos:***
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64
# *** Lista de 5 productos menos vendidos: ***
# Producto
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
print(f'Envío promedio de Tienda 1: {tienda["Costo de envío"].mean():,.2f}')
print(f'Envío promedio de Tienda 2: {tienda2["Costo de envío"].mean():,.2f}')
print(f'Envío promedio de Tienda 3: {tienda3["Costo de envío"].mean():,.2f}')
print(f'Envío promedio de Tienda 4: {tienda4["Costo de envío"].mean():,.2f}')
# Out:
# Envío promedio de Tienda 1: 26,018.61
# Envío promedio de Tienda 2: 25,216.24
# Envío promedio de Tienda 3: 24,805.68
# Envío promedio de Tienda 4: 23,459.46

# %%
import matplotlib.pyplot as plt

# Gráfica de Pie para 'Categoría del Producto' (en base a artículos) para Tienda 4
category_counts_tienda4 = tienda['Categoría del Producto'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(category_counts_tienda4, labels=category_counts_tienda4.index, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title('Distribución de Ventas por Categoría de Producto (Tienda 4)')
plt.axis('equal')
plt.show()

# Gráfica de Pie para 'Cantidad de Ventas' (ingresos totales por categoría) para Tienda 4
category_revenue_tienda4 = tienda.groupby('Categoría del Producto')['Precio'].sum()
plt.figure(figsize=(8, 6))
plt.pie(category_revenue_tienda4, labels=category_revenue_tienda4.index, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title('Distribución de Ingresos por Categoría de Producto (Tienda 4)')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Informe final
# Con base en los análisis realizados y los gráficos generados, es momento de sintetizar sus hallazgos en un informe final. Dentro de tu Colab, deberás redactar un texto explicando a qué tienda debe vender el Sr. Juan, teniendo en cuenta todos los factores analizados, como:
#
# Los ingresos totales de las tiendas.
#
# Las categorías de productos más y menos vendidas.
#
# Las calificaciones promedio de los clientes por tienda.
#
# Los productos más y menos vendidos.
#
# El coste de envío promedio para cada tienda.
#
# En su informe, incluya la justificación de su decisión, respaldada por el análisis y las visualizaciones que generó. Explicar, de forma clara y objetiva, las razones por las que una tienda destaca (o no) en relación a las demás, considerando las fortalezas y debilidades de cada una.
#
# Su informe debe estar bien estructurado, con una introducción que explique el propósito del análisis, un desarrollo con la presentación de datos y gráficos, y una conclusión recomendando la tienda que se debe vender y justificando la elección.

# %% [markdown]
# ### De acuerdo a los datos proporcionados y al análisis de los mismos, la tienda objeto para cierre o reestructura es la número 4, ello en base a lo siguiente:
# * En primera instancia, sus ingresos son menores respecto de las 3 primeras con un monto de $1'038,375,700.00.
# * La diferencia de ingresos respecto de la "Tienda1" es de 112,504,700.00
# * Su calificación promedio es de 4.00 incluso 2 unidades mayor que la "Tienda1" que es la que más ventas genera.
# * Sus productos menos vendidos son:
#
#       -Refrigerador                   38
#       -Ciencia de datos con Python    38
#       -Guitarra acústica              37
#       -Armario                        34
#       -Guitarra eléctrica             33
#
# * Envío promedio de Tienda 4: 23,459.46, lo cual es relativamente igual que sus pares que tienen ventas más significativas, indicativo de que el cliente está pagando más por envío en artículos vendidos.
# * La venta de muebles significa un 19.7% pero respecto de sus ingresos representa un 16.3%, siendo la categoría que más vende en las demás tiendas.
#
# ##### Por lo anterior, la recomendación es reestructurar o cerrar/vender la "Tienda 4"
